# %%
# print a .ttl represention of the Linked.Art JSON-LD context. Probably, evil; useful for me.

import urllib.request, json 

with urllib.request.urlopen("https://linked.art/ns/v1/linked-art.json") as url:
    json_context = json.loads(url.read().decode())['@context']

print('@prefix owl: <http://www.w3.org/2002/07/owl#> .')
    
for key in json_context.keys():
    if (type(json_context[key]) is str) and (json_context[key][0].islower()):
        print('@prefix {}: <{}> .'.format(key,json_context[key]))

    if type(json_context[key]) is dict:
        if key[0].isupper():
            print('''la:{0} a rdfs:Class;
   rdfs:label "{0}";
   owl:sameClassAs {1} .
   '''.format(key,json_context[key]['@id']))
        else:
            print('''la:{0} a rdf:Property;
   rdfs:label "{0}";
   owl:samePropertyAs {1} .
   '''.format(key,json_context[key]['@id']))
# Out:
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix crm: <http://www.cidoc-crm.org/cidoc-crm/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix schema: <http://schema.org/> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix ore: <http://www.openarchives.org/ore/terms/> .
# @prefix la: <https://linked.art/ns/terms/> .
# @prefix aat: <http://vocab.getty.edu/aat/> .
# @prefix ulan: <http://vocab.getty.edu/ulan/> .
# @prefix tgn: <http://vocab.getty.edu/tgn/> .
# la:Activity a rdfs:Class;
#    rdfs:label "Activity";
#    owl:sameClassAs crm:E7_Activity .
#
# la:Acquisition a rdfs:Class;
#    rdfs:label "Acquisition";
#    owl:sameClassAs crm:E8_Acquisition .
#
# ...
